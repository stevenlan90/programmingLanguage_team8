# %% [markdown]
# #versionOne

# %%
import json
import sys
import pandas as pd
import requests

# %%
res = requests.get('https://api.thevirustracker.com/free-api?countryTimeline=US')
arr = res.json()
items = arr['timelineitems'][0]

# %%
dates=list(items.keys())
dates.remove(dates[-1])
caseCount = [(items[key]['total_cases'])for key in items if key!='stat']

# %%
import matplotlib.pyplot as plt
x = dates
y = caseCount
plt.plot(x, y)
plt.xlabel('date')
plt.ylabel('case')
plt.show()

# %% [markdown]
# #versionTwo

# %%
import json
import sys
import pandas as pd
import requests
import matplotlib.pyplot as plt

URL = "https://api.thevirustracker.com/free-api?countryTimeline="

while True:
    
    

    countryCode = input("please input country code: ")
    
    if countryCode == '0':
        break

    res = requests.get(URL + countryCode)

    arr = res.json()
    items = arr['timelineitems'][0]
    dates=list(items.keys())
    dates.remove(dates[-1])
    caseCount = [(items[key]['total_cases'])for key in items if key!='stat']

    x = dates
    y = caseCount
    plt.plot(x, y)
    plt.xlabel('date')
    plt.ylabel('case')
    plt.show()
# Out:
# please input country code: AF
# please input country code: AL
# please input country code: AT
# please input country code: TW
